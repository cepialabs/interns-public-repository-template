# %%
#1. Write a simple Python program to print an output
print("Hello, World!")
# Out:
# Hello, World!

# %%
#2. Write a Python code to check if a number is even or odd
def is_even(num):
    return num % 2 == 0

print(is_even(4))
print(is_even(5))
# Out:
# True
# False

# %%
#3. Write a Python code to concatenate two strings
str1 = "Hello"
str2 = "World"
result = str1 + " " + str2
print(result)
# Out:
# Hello World

# %%
#4. Write a Python program to find the maximum of three numbers
def max_of_three(a, b, c):
    return max(a, b, c)

print(max_of_three(1, 2, 3))
# Out:
# 3

# %%
#5. Write a Python program to count the number of vowels in a string
def count_vowels(s):
    return sum(1 for char in s if char.lower() in 'aeiou')

print(count_vowels("Hello World"))
# Out:
# 3

# %%
#6. Write a Python program to calculate the factorial of a number
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %%
#6. Write a Python program to calculate the factorial of a number
str_num = "12345"
int_num = int(str_num)
print(int_num)
# Out:
# 12345

# %%
#8. Write a Python program to calculate the area of a rectangle
def area_of_rectangle(length, width):
    return length * width

print(area_of_rectangle(5, 3))
# Out:
# 15

# %%
#9. How do you calculate the factorial of a number in Python?
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %%
#10. Write a Python code to check if a number is prime.
def is_prime(num):
    if num <= 1:
        return False

    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

print(is_prime(7))
print(is_prime(10))
# Out:
# True
# False

# %%
#11. Write a program in Python to determine whether a number is a palindrome.
def is_palindrome(number):
    return str(number) == str(number)[::-1]

print(is_palindrome(121))
print(is_palindrome(123))
# Out:
# True
# False

# %%
#12. Write a program in Python to determine whether a number is an Armstrong number.
def is_armstrong(number):
    num_str = str(number)
    power = len(num_str)
    return number == sum(int(digit) ** power for digit in num_str)

print(is_armstrong(153))
print(is_armstrong(123))
# Out:
# True
# False

# %%
#13. Write a program using Python that finds out if a number is a perfect number.
def is_perfect_number(number):
    if number <= 0:
        return False
    return sum(i for i in range(1, number) if number % i == 0) == number

print(is_perfect_number(28))
print(is_perfect_number(12))
# Out:
# True
# False

# %%
#14. Write a Python program to determine if a year is a leap year.
def is_leap_year(year):
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

print(is_leap_year(2024))
print(is_leap_year(2023))
# Out:
# True
# False

# %%
#15. Write a Python program to calculate the factorial of a number.
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %%
#16. Create a program in Python that can generate a Fibonacci sequence with up to n terms.
def fibonacci(n):
    sequence = [0, 1]
    for i in range(2, n):
        sequence.append(sequence[-1] + sequence[-2])
    return sequence[:n]

print(fibonacci(7))
# Out:
# [0, 1, 1, 2, 3, 5, 8]

# %%
#17. Write a Python program to calculate the sum of digits in a number.
def sum_of_digits(number):
    return sum(int(digit) for digit in str(number))

print(sum_of_digits(123))
# Out:
# 6

# %%
#17. Write a Python program to calculate the sum of digits in a number.
def decimal_to_binary(decimal):
    return bin(decimal)[2:]

print(decimal_to_binary(10))
# Out:
# 1010

# %%
#19. How do you check if a number is a prime factor of another number in Python?
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

def is_prime_factor(number, factor):
    return is_prime(factor) and number % factor == 0

print(is_prime_factor(15, 3))
print(is_prime_factor(15, 4))
# Out:
# True
# False

# %%
#20. How do you use a function to find all prime numbers within a given range in Python?
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

def find_primes(start, end):
    return [num for num in range(start, end + 1) if is_prime(num)]

print(find_primes(1, 10))
# Out:
# [2, 3, 5, 7]

# %%
#Why I Want to Build a Career in AI/ML 

 I Developed a strong interest in AI/ML while working on the AI-Enhanced Driver Wellness project, where I observed how intelligent systems can improve human safety and decision-making.

Gained hands-on experience with rule-based algorithms, which helped me understand how predefined logic can be used to model system behavior and make decisions.

Explored Machine Learning concepts using the Naive Bayes algorithm, learning how models can automatically identify patterns and make predictions from data.

Understood the key difference between rule-based systems and data-driven ML models, which increased my curiosity to learn advanced ML techniques.

Realized the real-world impact of AI/ML in areas such as driver safety, behavioral analysis, and wellness monitoring.

Motivated to build scalable, adaptive, and intelligent systems rather than relying only on static logic.

Interested in continuous learning, experimentation, and applying AI/ML ethically to solve real-world problems.

Aspire to grow as an AI/ML professional who contributes to impactful projects that enhance safety, efficiency, and quality of life.
